# %% [markdown]
# ## Problem Statement - GDP and For Loop

# %% [markdown]
# ## GDP

# %%
import pandas as pd  ###Software library written for the Python programming language for data manipulation and analysis.
import numpy as np ### fundamental package for scientific computing with Python
import os ### using operating system dependent functionality

# %% [markdown]
# # Set the working directory

# %%
os.chdir('/Users/Amit.Jain/Desktop/PGP-DSBA/')

# %% [markdown]
# # Import Excel file

# %% [markdown]
# Load the Data file into Python DataFrame using pandas read_excel method

# %% [markdown]
# The csv that we are going to load contains the unicode format data. We will use an additional encoding parameter which will allow pandas to load the csv.

# %%
data_df = pd.read_excel("GDP_Dataset.xlsx")

# %% [markdown]
# # View Top 10 rows

# %% [markdown]
# head function is used to view the top records. The number records to be view need to be  given in the parenthesis.

# %%
data_df.head(10)
# Out:
#    S.No        Country  Population  Yearly_Change  Land_Area  \
# 0     1          China  1421021791           0.39    9388211
# 1     2          India  1338676785           0.99    2973190
# 2     3  United States   325084756           0.59    9147420
# 3     4      Indonesia   264650963           1.07    1811570
# 4     5       Pakistan   207906209           2.00     770880
# 5     6         Brazil   207833823           0.72    8358140
# 6     7        Nigeria   190873244           2.58     910770
# 7     8     Bangladesh   159685424           1.01     130170
# 8     9         Russia   145530082           0.04   16376870
# 9    10         Mexico   127502725           1.06    1943950
#
#    Population_Density  Migrants_Net  Median_Age  Urban_Population  \
# 0          151.362362       -348399          38              61.0
# 1          450.249323       -532687          28              35.0
# 2           35.538409        954806          38              83.0
# 3          146.089283        -98955          30              56.0
# 4          269.699835       -233379          23              35.0
# 5           24.866038         21200          33              88.0
# 6          209.573486        -60000          18              52.0
# 7         1226.745210       -369501          28              39.0
# 8            8.886318        182456          40              74.0
# 9           65.589508        -60000          29              84.0
#
#    World_Share_in_Population      GDP  GDP_per_Capita  Share_of_World_GDP  \
# 0                      18.47  12238.0        8.612113               15.12
# 1                      17.70   2651.0        1.980314                3.28
# 2                       4.25  19485.0       59.938215               24.08
# 3                       3.51   1015.0        3.835240                1.25
# 4                       2.83    305.0        1.467008                0.38
# 5                       2.73   2054.0        9.882896                2.54
# 6                       2.64    376.0        1.969894                0.46
# 7                       2.11    250.0        1.565578                0.31
# 8                       1.87   1578.0       10.843119                1.95
# 9                       1.65   1151.0        9.027258                1.42
#
#        Status  Unnamed: 14  Unnamed: 15
# 0  Developing          NaN          NaN
# 1  Developing          NaN          NaN
# 2   Developed          NaN          NaN
# 3  Developing          NaN          NaN
# 4  Developing          NaN          NaN
# 5  Developing          NaN          NaN
# 6  Developing          NaN          NaN
# 7  Developing          NaN          NaN
# 8  Developing          NaN          NaN
# 9  Developing          NaN          NaN

# %%
# Out:
#      S.No              Country  Population  Yearly_Change  Land_Area  \
# 0       1                China  1421021791           0.39    9388211
# 1       2                India  1338676785           0.99    2973190
# 2       3        United States   325084756           0.59    9147420
# 3       4            Indonesia   264650963           1.07    1811570
# 4       5             Pakistan   207906209           2.00     770880
# ..    ...                  ...         ...            ...        ...
# 167   181              Vanuatu       77001           2.42      12190
# 168   183             Barbados       58058           0.12        430
# 169   187  Sao Tome & Principe       33671           1.91        960
# 170   188                Samoa       17808           0.67       2830
# 171   189          Saint Lucia       11370           0.46        610
#
#      Population_Density  Migrants_Net  Median_Age  Urban_Population  \
# 0            151.362362       -348399          38              61.0
# 1            450.249323       -532687          28              35.0
# 2             35.538409        954806          38              83.0
# 3            146.089283        -98955          30              56.0
# 4            269.699835       -233379          23              35.0
# ..                  ...           ...         ...               ...
# 167            6.316735           120          21              24.0
# 168          135.018605           -79          40              31.0
# 169           35.073958         -1680          19              74.0
# 170            6.292580         -2803          22              18.0
# 171           18.639344             0          34              19.0
#
#      World_Share_in_Population        GDP  GDP_per_Capita  Share_of_World_GDP  \
# 0                        18.47  12238.000        8.612113               15.12
# 1                        17.70   2651.000        1.980314                3.28
# 2                         4.25  19485.000       59.938215               24.08
# 3                         3.51   1015.000        3.835240                1.25
# 4                         2.83    305.000        1.467008                0.38
# ..                         ...        ...             ...                 ...
# 167                       0.00      0.863       11.207647                0.00
# 168                       0.00      4.670       80.436805                0.01
# 169                       0.00      0.393       11.671765                0.00
# 170                       0.00      0.841       47.225966                0.00
# 171                       0.00      1.740      153.034301                0.00
#
#          Status  Unnamed: 14  Unnamed: 15
# 0    Developing          NaN          NaN
# 1    Developing          NaN          NaN
# 2     Developed          NaN          NaN
# 3    Developing          NaN          NaN
# 4    Developing          NaN          NaN
# ..          ...          ...          ...
# 167  Developing          NaN          NaN
# 168  Developing          NaN          NaN
# 169  Developing          NaN          NaN
# 170  Developing          NaN          NaN
# 171  Developing          NaN          NaN
#
# [172 rows x 16 columns]

# %%
data_df_val= data_df.loc[data_df["Country"]== "Mexico"]['GDP (in $ Billions )'].values[0]
data_df_val
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GDP (in $ Billions )'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-3c247d3f2f0c> in <module>
# ----> 1 data_df_val= data_df.loc[data_df["Country"]== "Mexico"]['GDP (in $ Billions )'].values[0]
#       2 data_df_val
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'GDP (in $ Billions )'

# %%
new_subset= data_df[data_df["GDP (in $ Billions )"]> data_df_val]
new_subset.size
# Out:
# 182

# %% [markdown]
# ## Compare the array values in a for loop

# %%
arr = [10, 324, 45, 90, 9808]

# %%
max=arr[0] ## Initialize a max variable with the first element in an array
max
# Out:
# 10

# %%
n = len(arr)
n
# Out:
# 5

# %%
 for i in range(1, n):
        if arr[i] > max:
            max = arr[i]

# %%
print(max)
# Out:
# 9808
