# %%
import pandas as pd
import seaborn as sns   # Why sns?  It's a reference to The West Wing
import matplotlib.pyplot as plt  # seaborn is based on matplotlib
sns.set(color_codes=True) # adds a nice background to the graphs
# %matplotlib inline 
# tells python to actually display the graphs

# %%
auto = pd.read_csv('Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Plotting univariate distributions
#
# The most convenient way to take a quick look at a univariate distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).

# %%
print(auto.value_counts("highway_mpg").head(10))
print(auto.groupby("highway_mpg")["highway_mpg"].count().sort_values(ascending=False).head(5))
sns.displot(auto['highway_mpg']);
# Out:
# highway_mpg
# 25    19
# 38    17
# 24    17
# 30    16
# 32    16
# 34    14
# 37    13
# 28    12
# 29    10
# 33     9
# dtype: int64
# highway_mpg
# 25    19
# 38    17
# 24    17
# 30    16
# 32    16
# Name: highway_mpg, dtype: int64

# %%
# we can turn the kde off and put a tic mark along the x-axis for every data point with rug
sns.displot(auto['highway_mpg'], kde=True, rug=True);

# %% [markdown]
# ## Plotting bivariate distributions
#
# It can also be useful to visualize a relationship between two variables. The easiest way to do this in seaborn is to use the jointplot() function, which creates a scatterplot of the two variables along with the histograms of each next to the appropriate axes.

# %%
sns.jointplot(auto['engine_size'], auto['horsepower']);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Hex Bin Plots
#
# We can make a hex bin plot that breaks the 2D area into hexagons and the number of points in each hexagon determines the color

# %%
sns.jointplot(auto['engine_size'], auto['horsepower'], kind="hex");
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Kernel Density Estimation
#
# We can make a 2D estimation of the density also

# %%
sns.jointplot(auto['engine_size'], auto['horsepower'], kind="kde");
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Visualizing pairwise relationships in a dataset
#
# To plot multiple pairwise scatterplots in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame, it also draws the histogram of each variable on the diagonal Axes:
#
# Be careful about toggle scrolling in the cell menu!!!

# %%
sns.pairplot(auto[['normalized_losses', 'engine_size', 'horsepower']]);

# %% [markdown]
# ## Plotting with categorical data

# %% [markdown]
# In a strip plot, the scatterplot points will usually overlap. This makes it difficult to see the full distribution of data. One easy solution is to adjust the positions (only along the categorical axis) using “jitter"

# %%
sns.stripplot(auto['fuel_type'], auto['horsepower'], jitter=True);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# A different approach would be to use the function swarmplot(), which positions each scatterplot point on the categorical axis and avoids overlapping points:

# %%
sns.swarmplot(auto['fuel_type'], auto['horsepower']);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Boxplots
#
# Another common graph is a boxplot(). This kind of plot shows the three quartile values of the distribution along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile, and then observations that fall outside this range are displayed independently.

# %%
sns.boxplot(auto['number_of_doors'], auto['horsepower']);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(auto['number_of_doors'], auto['horsepower'], hue=auto['fuel_type']);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Bar plots
#
# We can plot the mean of a a dataset, separated in categories using the barplot() function. When there are multiple observations in each category, it uses bootstrapping to compute a confidence interval around the estimate and plots that using error bars:
#
# Bar plots start at 0, which can sometimes be practical if zero is a number you want to compare to

# %%
sns.barplot(auto['body_style'], auto['horsepower'], hue=auto['fuel_type']);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# A special case for the bar plot is when you want to show the number of observations in each category rather than computing the mean of a second variable. This is similar to a histogram over a categorical, rather than quantitative, variable. In seaborn, it’s easy to do so with the countplot() function:

# %%
sns.countplot(auto['body_style'],hue=auto['fuel_type']);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Point plots
#
# An alternative style for visualizing the same information is offered by the pointplot() function. This function also encodes the value of the estimate with height on the other axis, but rather than show a full bar it just plots the point estimate and confidence interval. Additionally, pointplot connects points from the same hue category. This makes it easy to see how the main relationship is changing as a function of a second variable, because your eyes are quite good at picking up on differences of slopes:

# %%
sns.pointplot(auto['body_style'], auto['horsepower'], hue=auto['number_of_doors']);
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Drawing multi-panel categorical plots

# %%
sns.catplot(x="fuel_type",
               y = "horsepower",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="box");

# %% [markdown]
# Various types of kind input : {``point``, ``bar``, ``count``, ``box``, ``violin``, ``strip``}

# %% [markdown]
# ## Function to draw linear regression models
#
# lmplot() is one of the most widely used function to quickly plot the Linear Relationship between 2 variables

# %%
sns.lmplot(y="horsepower", x="engine_size", data=auto);

# %%
sns.lmplot(y="horsepower", x="engine_size",hue="fuel_type", data=auto);

# %%
# Out:
#                                           product name        asin  \
# 0    BHAGIRATH Standard comfort Disposable Pollutio...  B085GL266P
# 1    ShopyBucket Standard 3 PCS comfort Disposable ...  B0855V7MQ8
# 2    Gnexin ISI Approved Mask RespiratorPollutionAn...  B084M511KM
# 3    Kodenipr Club Disposable Stretchable Blue Bouf...  B0777HKWJF
# 4                  SMARTCARE Face Mask Cloth Tie Green  B079CHH5M3
# ..                                                 ...         ...
# 204  SARAF Assorted Anti-Dust respiratory Woven Fac...  B085MBKQXR
# 205   Agarwals™ Airway Silicon Size 00012346 Pack Of 7  B0852Q32KH
# 206                   Saviour Bouffant Cap Pack Of 100  B083Q75L4F
# 207  Romsons Vein O Line GS- 3034 Extension tube wi...  B01M98TQWG
# 208          Agarwals™ Airway Silicon Size 3 Pack Of 1  B0852PMZBH
#
#                                            product url     brand name  \
# 0    https://www.amazon.in/BHAGIRATH-Standard-Dispo...  Bhagirath fab
# 1    https://www.amazon.in/ShopyBucket-Standard-Dis...          Shopy
# 2    https://www.amazon.in/Gnexin-Approved-Respirat...         Gnexin
# 3    https://www.amazon.in/Aurum-Creations-Disposab...  KODENIPR CLUB
# 4    https://www.amazon.in/Smart-Care-Face-Cloth-Gr...      SMARTCARE
# ..                                                 ...            ...
# 204  https://www.amazon.in/SARAF-Assorted-Anti-Dust...          SARAF
# 205  https://www.amazon.in/AgarwalsTM-Airway-Silico...       Agarwals
# 206  https://www.amazon.in/Saviour-Bouffant-Cap-Pac...        Saviour
# 207  https://www.amazon.in/Romsons-Vein-Extension-3...        Romsons
# 208  https://www.amazon.in/AgarwalsTM-Airway-Silico...       Agarwals
#
#                                              image url    mrp  sale price  \
# 0    https://images-na.ssl-images-amazon.com/images...  16999         199
# 1    https://images-na.ssl-images-amazon.com/images...    798         510
# 2    https://images-na.ssl-images-amazon.com/images...    299         299
# 3    https://images-na.ssl-images-amazon.com/images...    299          60
# 4    https://images-na.ssl-images-amazon.com/images...   1000         250
# ..                                                 ...    ...         ...
# 204  https://images-na.ssl-images-amazon.com/images...    499         299
# 205  https://images-na.ssl-images-amazon.com/images...   6800        2699
# 206  https://images-na.ssl-images-amazon.com/images...    599         399
# 207  https://images-na.ssl-images-amazon.com/images...    302          79
# 208  https://images-na.ssl-images-amazon.com/images...   2600         499
#
#      discount percentage                                product description  \
# 0                   0.99  IND mask covers the user’s nose and mouth and ...
# 1                   0.36                                        Dummy text
# 2                   0.00  Clair filters presents you Pollution mask ISI ...
# 3                   0.80  Disposable cap is produced using spun bond pol...
# 4                   0.75  Cloth Face masks. Used in medical  dental  lab...
# ..                   ...                                                ...
# 204                 0.40  YAYA Surgical Mask are made of cotton and soft...
# 205                 0.60  This are made of silicon and available in diff...
# 206                 0.33  Bouffant Cap – 18 Inches with Thread Elastic. ...
# 207                 0.74                                        Dummy text
# 208                 0.81  This are made of silicon and available in diff...
#
#     date first available  number of reviews  \
# 0       01-03-2020 00:00                  0
# 1       26-02-2020 00:00                  0
# 2       09-02-2020 00:00                  2
# 3       09-08-2017 00:00                199
# 4       28-01-2018 00:00                  1
# ..                   ...                ...
# 204     05-03-2020 00:00                  0
# 205     23-02-2020 00:00                  0
# 206     09-01-2020 00:00                  0
# 207     10-10-2016 00:00                  0
# 208     23-02-2020 00:00                  0
#
#                                 seller name
# 0                             Bhagirath fab
# 1                                 BasicDeal
# 2                       ONESENSE ENTERPRISE
# 3    Genesis Lifesciences (India) Pvt. Ltd.
# 4              Aastha Uniform and Overgowns
# ..                                      ...
# 204                             SARAF-INDIA
# 205                        AGARWAL SURGICAL
# 206                 Sure Safety (I) Pvt Ltd
# 207               shree krishna health care
# 208                        AGARWAL SURGICAL
#
# [209 rows x 12 columns]
